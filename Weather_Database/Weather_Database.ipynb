# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities

cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
   
# Use the citipy module to identify the nearest city to the current coordinate
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city

city_data = []

# Print a message to indicate that the data retrieval starts

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1

record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | hamilton
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | rush
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | puga
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | mutoko
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | naron
# Processing Record 18 of Set 1 | kortkeros
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | sisimiut
# Processing Record 25 of Set 1 | marechal candido rondon
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | hirara
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | lubango
# Processing Record 31 of Set 1 | mahibadhoo
# Processing Record 32 of Set 1 | bonavista
# Processing Record 33 of Set 1 | balsas
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | port lincoln
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | korla
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | qasigiannguit
# Processing Record 44 of Set 1 | darhan
# Processing Record 45 of Set 1 | banda aceh
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | maniitsoq
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | shubarkuduk
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | erbaa
# Processing Record 6 of Set 2 | lensk
# Processing Record 7 of Set 2 | russell
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | awjilah
# Processing Record 11 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 14 of Set 2 | half moon bay
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | arraias
# Processing Record 17 of Set 2 | jurmala
# Processing Record 18 of Set 2 | san cristobal
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | tukrah
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | thongwa
# Processing Record 29 of Set 2 | henties bay
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | maceio
# Processing Record 32 of Set 2 | tilichiki
# Processing Record 33 of Set 2 | maputo
# Processing Record 34 of Set 2 | nhulunbuy
# Processing Record 35 of Set 2 | dunedin
# Processing Record 36 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | kasongo-lunda
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 2 | xilagani
# Processing Record 45 of Set 2 | santa marta
# Processing Record 46 of Set 2 | ghogha
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | ushtobe
# Processing Record 49 of Set 2 | tarsus
# Processing Record 50 of Set 2 | mecca
# Processing Record 1 of Set 3 | yeppoon
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | pacific grove
# Processing Record 5 of Set 3 | isangel
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | san policarpo
# Processing Record 8 of Set 3 | yambio
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | dwarka
# Processing Record 15 of Set 3 | erenhot
# Processing Record 16 of Set 3 | coihaique
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | balkhash
# Processing Record 19 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | manjacaze
# Processing Record 22 of Set 3 | reconquista
# Processing Record 23 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | timberlake
# Processing Record 29 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 3 | berlevag
# Processing Record 31 of Set 3 | altay
# Processing Record 32 of Set 3 | siuna
# Processing Record 33 of Set 3 | kozmodemyansk
# Processing Record 34 of Set 3 | nehe
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | chak jhumra
# Processing Record 38 of Set 3 | kushmurun
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | hounde
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | ionia
# Processing Record 44 of Set 3 | asansol
# Processing Record 45 of Set 3 | saint-francois
# Processing Record 46 of Set 3 | akure
# Processing Record 47 of Set 3 | jining
# Processing Record 48 of Set 3 | coruripe
# Processing Record 49 of Set 3 | kindu
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 4 | aswan
# Processing Record 4 of Set 4 | cody
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | adwa
# Processing Record 7 of Set 4 | langsa
# Processing Record 8 of Set 4 | shaygino
# Processing Record 9 of Set 4 | camacha
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | ratnagiri
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | mbaiki
# Processing Record 16 of Set 4 | manta
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | alta floresta
# Processing Record 19 of Set 4 | wangaratta
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | barcelos
# Processing Record 22 of Set 4 | kiunga
# Processing Record 23 of Set 4 | sylvan lake
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | campos belos
# Processing Record 26 of Set 4 | guiglo
# Processing Record 27 of Set 4 | umm lajj
# Processing Record 28 of Set 4 | skelleftea
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 4 | egvekinot
# Processing Record 32 of Set 4 | ferme-neuve
# Processing Record 33 of Set 4 | jos
# Processing Record 34 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 4 | monte cristi
# City not found. Skipping...
# Processing Record 36 of Set 4 | varhaug
# Processing Record 37 of Set 4 | arona
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | evensk
# Processing Record 40 of Set 4 | yumen
# Processing Record 41 of Set 4 | osakasayama
# Processing Record 42 of Set 4 | pemba
# Processing Record 43 of Set 4 | benjamin hill
# Processing Record 44 of Set 4 | yar-sale
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | santa marinella
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | arman
# Processing Record 1 of Set 5 | coquimbo
# Processing Record 2 of Set 5 | georgetown
# Processing Record 3 of Set 5 | vagur
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | myitkyina
# Processing Record 6 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 7 of Set 5 | touros
# Processing Record 8 of Set 5 | kirovskiy
# Processing Record 9 of Set 5 | kloulklubed
# Processing Record 10 of Set 5 | den helder
# Processing Record 11 of Set 5 | iquique
# Processing Record 12 of Set 5 | auki
# Processing Record 13 of Set 5 | bairiki
# Processing Record 14 of Set 5 | maragogi
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | maracacume
# Processing Record 17 of Set 5 | hasaki
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | turiacu
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | chapais
# Processing Record 22 of Set 5 | matadi
# Processing Record 23 of Set 5 | mgandu
# Processing Record 24 of Set 5 | ouahigouya
# Processing Record 25 of Set 5 | khuzhir
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | bakchar
# Processing Record 30 of Set 5 | osoyoos
# Processing Record 31 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 5 | mitsamiouli
# Processing Record 33 of Set 5 | cherskiy
# Processing Record 34 of Set 5 | luau
# Processing Record 35 of Set 5 | agadez
# Processing Record 36 of Set 5 | cahors
# Processing Record 37 of Set 5 | kuching
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | lahaina
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | moron
# Processing Record 44 of Set 5 | plumlov
# Processing Record 45 of Set 5 | champerico
# Processing Record 46 of Set 5 | kaili
# Processing Record 47 of Set 5 | george town
# Processing Record 48 of Set 5 | tuapse
# Processing Record 49 of Set 5 | sayyan
# Processing Record 50 of Set 5 | petropavl
# Processing Record 1 of Set 6 | saint-philippe
# Processing Record 2 of Set 6 | sorong
# Processing Record 3 of Set 6 | remiremont
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | kyela
# Processing Record 6 of Set 6 | zhigansk
# Processing Record 7 of Set 6 | maumere
# Processing Record 8 of Set 6 | chenzhou
# Processing Record 9 of Set 6 | san jose de guanipa
# Processing Record 10 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 6 | jacareacanga
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | marawi
# Processing Record 15 of Set 6 | airai
# Processing Record 16 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 6 | banjar
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | sabang
# Processing Record 20 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 6 | matto
# City not found. Skipping...
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | hovd
# Processing Record 24 of Set 6 | golden
# Processing Record 25 of Set 6 | amga
# Processing Record 26 of Set 6 | mantua
# Processing Record 27 of Set 6 | boali
# Processing Record 28 of Set 6 | wahiawa
# Processing Record 29 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 6 | kenai
# Processing Record 31 of Set 6 | kalashnikovo
# Processing Record 32 of Set 6 | biak
# Processing Record 33 of Set 6 | bethel
# Processing Record 34 of Set 6 | luganville
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | nemuro
# Processing Record 37 of Set 6 | morondava
# Processing Record 38 of Set 6 | vardo
# Processing Record 39 of Set 6 | liverpool
# Processing Record 40 of Set 6 | iskitim
# Processing Record 41 of Set 6 | bayanday
# Processing Record 42 of Set 6 | escuinapa
# Processing Record 43 of Set 6 | kolvereid
# Processing Record 44 of Set 6 | salta
# Processing Record 45 of Set 6 | khrebtovaya
# Processing Record 46 of Set 6 | san pedro
# Processing Record 47 of Set 6 | katol
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | marica
# Processing Record 50 of Set 6 | teya
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | kysyl-syr
# Processing Record 3 of Set 7 | torbay
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | high level
# Processing Record 6 of Set 7 | bacolod
# Processing Record 7 of Set 7 | pundaguitan
# Processing Record 8 of Set 7 | angra
# City not found. Skipping...
# Processing Record 9 of Set 7 | cabo san lucas
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | jijiga
# Processing Record 12 of Set 7 | burica
# City not found. Skipping...
# Processing Record 13 of Set 7 | lang son
# Processing Record 14 of Set 7 | pskov
# Processing Record 15 of Set 7 | singaparna
# Processing Record 16 of Set 7 | haines junction
# Processing Record 17 of Set 7 | bystryy istok
# Processing Record 18 of Set 7 | maragheh
# Processing Record 19 of Set 7 | kieta
# Processing Record 20 of Set 7 | kautokeino
# Processing Record 21 of Set 7 | abnub
# Processing Record 22 of Set 7 | non sang
# Processing Record 23 of Set 7 | juneau
# Processing Record 24 of Set 7 | quatre cocos
# Processing Record 25 of Set 7 | niamey
# Processing Record 26 of Set 7 | mendoza
# Processing Record 27 of Set 7 | porto novo
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | dinguiraye
# Processing Record 30 of Set 7 | port hedland
# Processing Record 31 of Set 7 | ananas
# Processing Record 32 of Set 7 | tautira
# Processing Record 33 of Set 7 | almaznyy
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | mar del plata
# Processing Record 36 of Set 7 | neiafu
# Processing Record 37 of Set 7 | ormara
# Processing Record 38 of Set 7 | padang
# Processing Record 39 of Set 7 | conde
# Processing Record 40 of Set 7 | hambantota
# Processing Record 41 of Set 7 | tezu
# Processing Record 42 of Set 7 | sao felix do xingu
# Processing Record 43 of Set 7 | mayo
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 7 | boundiali
# Processing Record 47 of Set 7 | cintalapa
# Processing Record 48 of Set 7 | lucapa
# Processing Record 49 of Set 7 | warri
# Processing Record 50 of Set 7 | gat
# Processing Record 1 of Set 8 | sorland
# Processing Record 2 of Set 8 | mezen
# Processing Record 3 of Set 8 | pirgos
# Processing Record 4 of Set 8 | ternate
# Processing Record 5 of Set 8 | gayeri
# Processing Record 6 of Set 8 | chirongui
# Processing Record 7 of Set 8 | sturgeon falls
# Processing Record 8 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 9 of Set 8 | antofagasta
# Processing Record 10 of Set 8 | pevek
# Processing Record 11 of Set 8 | iralaya
# Processing Record 12 of Set 8 | seoul
# Processing Record 13 of Set 8 | chimoio
# Processing Record 14 of Set 8 | koungheul
# Processing Record 15 of Set 8 | vestmannaeyjar
# Processing Record 16 of Set 8 | chulumani
# Processing Record 17 of Set 8 | pangkalanbuun
# Processing Record 18 of Set 8 | berbera
# Processing Record 19 of Set 8 | ambulu
# Processing Record 20 of Set 8 | lovington
# Processing Record 21 of Set 8 | cabedelo
# Processing Record 22 of Set 8 | cobija
# Processing Record 23 of Set 8 | saint-pierre
# Processing Record 24 of Set 8 | mercedes
# Processing Record 25 of Set 8 | tuxpan
# Processing Record 26 of Set 8 | zelenogorskiy
# Processing Record 27 of Set 8 | harsin
# Processing Record 28 of Set 8 | bereda
# Processing Record 29 of Set 8 | kristiinankaupunki
# Processing Record 30 of Set 8 | luena
# Processing Record 31 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 8 | joshimath
# Processing Record 33 of Set 8 | okato
# Processing Record 34 of Set 8 | lisala
# Processing Record 35 of Set 8 | amalapuram
# Processing Record 36 of Set 8 | buala
# Processing Record 37 of Set 8 | bela
# Processing Record 38 of Set 8 | floro
# Processing Record 39 of Set 8 | borogontsy
# Processing Record 40 of Set 8 | mao
# Processing Record 41 of Set 8 | byron bay
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | muravlenko
# Processing Record 44 of Set 8 | nevel
# Processing Record 45 of Set 8 | houma
# Processing Record 46 of Set 8 | tselina
# Processing Record 47 of Set 8 | nabire
# Processing Record 48 of Set 8 | changli
# Processing Record 49 of Set 8 | esna
# Processing Record 50 of Set 8 | nerchinskiy zavod
# Processing Record 1 of Set 9 | port macquarie
# Processing Record 2 of Set 9 | puksoozero
# Processing Record 3 of Set 9 | longyearbyen
# Processing Record 4 of Set 9 | maasbree
# Processing Record 5 of Set 9 | puerto escondido
# Processing Record 6 of Set 9 | cairns
# Processing Record 7 of Set 9 | pangody
# Processing Record 8 of Set 9 | nouadhibou
# Processing Record 9 of Set 9 | likasi
# Processing Record 10 of Set 9 | bulawayo
# Processing Record 11 of Set 9 | manado
# Processing Record 12 of Set 9 | valentin gomez farias
# Processing Record 13 of Set 9 | mbandaka
# Processing Record 14 of Set 9 | muros
# Processing Record 15 of Set 9 | novyy yegorlyk
# Processing Record 16 of Set 9 | saint-michel-des-saints
# Processing Record 17 of Set 9 | bolivar
# Processing Record 18 of Set 9 | niwari
# Processing Record 19 of Set 9 | sao raimundo nonato
# Processing Record 20 of Set 9 | orsha
# Processing Record 21 of Set 9 | luderitz
# Processing Record 22 of Set 9 | palmer
# Processing Record 23 of Set 9 | andenes
# Processing Record 24 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 9 | fairbanks
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | ipixuna
# Processing Record 28 of Set 9 | khor
# Processing Record 29 of Set 9 | zhaotong
# Processing Record 30 of Set 9 | lesnoy
# Processing Record 31 of Set 9 | mabaruma
# Processing Record 32 of Set 9 | raahe
# Processing Record 33 of Set 9 | almenara
# Processing Record 34 of Set 9 | daru
# Processing Record 35 of Set 9 | lyuban
# Processing Record 36 of Set 9 | maningrida
# Processing Record 37 of Set 9 | lokosovo
# Processing Record 38 of Set 9 | shillong
# Processing Record 39 of Set 9 | teguise
# Processing Record 40 of Set 9 | vao
# Processing Record 41 of Set 9 | mareeba
# Processing Record 42 of Set 9 | yusva
# City not found. Skipping...
# Processing Record 43 of Set 9 | yabelo
# Processing Record 44 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 9 | sydney
# Processing Record 46 of Set 9 | bengkulu
# Processing Record 47 of Set 9 | gorontalo
# Processing Record 48 of Set 9 | kindersley
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | santa rosa
# Processing Record 1 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 10 | geraldton
# Processing Record 3 of Set 10 | hidalgotitlan
# Processing Record 4 of Set 10 | basirpur
# Processing Record 5 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 6 of Set 10 | college
# Processing Record 7 of Set 10 | shache
# Processing Record 8 of Set 10 | port-cartier
# Processing Record 9 of Set 10 | tutoia
# Processing Record 10 of Set 10 | pokosnoye
# Processing Record 11 of Set 10 | evanston
# Processing Record 12 of Set 10 | buguda
# Processing Record 13 of Set 10 | baracoa
# Processing Record 14 of Set 10 | san jose
# Processing Record 15 of Set 10 | narsaq
# Processing Record 16 of Set 10 | buba
# Processing Record 17 of Set 10 | waingapu
# Processing Record 18 of Set 10 | santa vitoria do palmar
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | panama city
# Processing Record 21 of Set 10 | wucheng
# Processing Record 22 of Set 10 | soyaux
# Processing Record 23 of Set 10 | nakhon sawan
# Processing Record 24 of Set 10 | axim
# Processing Record 25 of Set 10 | edd
# Processing Record 26 of Set 10 | muroto
# Processing Record 27 of Set 10 | mackenzie
# Processing Record 28 of Set 10 | villazon
# Processing Record 29 of Set 10 | oktyabrskoye
# Processing Record 30 of Set 10 | astana
# Processing Record 31 of Set 10 | bintulu
# Processing Record 32 of Set 10 | acapulco
# Processing Record 33 of Set 10 | ocos
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | severo-kurilsk
# Processing Record 36 of Set 10 | kampene
# Processing Record 37 of Set 10 | coahuayana
# Processing Record 38 of Set 10 | peniche
# Processing Record 39 of Set 10 | oshnaviyeh
# Processing Record 40 of Set 10 | palana
# Processing Record 41 of Set 10 | aksay
# Processing Record 42 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 10 | metabetchouan
# City not found. Skipping...
# Processing Record 44 of Set 10 | lamar
# Processing Record 45 of Set 10 | sinnamary
# Processing Record 46 of Set 10 | vari
# Processing Record 47 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 10 | marsh harbour
# Processing Record 49 of Set 10 | alem paraiba
# Processing Record 50 of Set 10 | cleburne
# Processing Record 1 of Set 11 | lumberton
# Processing Record 2 of Set 11 | vila franca do campo
# Processing Record 3 of Set 11 | rodos
# Processing Record 4 of Set 11 | ottawa
# Processing Record 5 of Set 11 | pacifica
# Processing Record 6 of Set 11 | nuuk
# Processing Record 7 of Set 11 | balykshi
# Processing Record 8 of Set 11 | praia da vitoria
# Processing Record 9 of Set 11 | cacapava do sul
# Processing Record 10 of Set 11 | takoradi
# Processing Record 11 of Set 11 | dingle
# Processing Record 12 of Set 11 | hervey bay
# Processing Record 13 of Set 11 | bay roberts
# Processing Record 14 of Set 11 | srednekolymsk
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | stony plain
# Processing Record 17 of Set 11 | olafsvik
# Processing Record 18 of Set 11 | santa comba
# Processing Record 19 of Set 11 | vilhena
# Processing Record 20 of Set 11 | bandiagara
# Processing Record 21 of Set 11 | colares
# Processing Record 22 of Set 11 | robore
# Processing Record 23 of Set 11 | caidian
# Processing Record 24 of Set 11 | maua
# Processing Record 25 of Set 11 | duz
# City not found. Skipping...
# Processing Record 26 of Set 11 | shimoda
# Processing Record 27 of Set 11 | ghanzi
# Processing Record 28 of Set 11 | suntar
# Processing Record 29 of Set 11 | la ronge
# Processing Record 30 of Set 11 | dano
# Processing Record 31 of Set 11 | plettenberg bay
# Processing Record 32 of Set 11 | chastoozerye
# City not found. Skipping...
# Processing Record 33 of Set 11 | sohagpur
# Processing Record 34 of Set 11 | lavrentiya
# Processing Record 35 of Set 11 | ponta pora
# Processing Record 36 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 37 of Set 11 | voh
# Processing Record 38 of Set 11 | tafo
# Processing Record 39 of Set 11 | otjimbingwe
# Processing Record 40 of Set 11 | ecoporanga
# Processing Record 41 of Set 11 | sayville
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | ostrovnoy
# Processing Record 44 of Set 11 | ambon
# Processing Record 45 of Set 11 | moree
# Processing Record 46 of Set 11 | xuddur
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | khasan
# Processing Record 49 of Set 11 | knysna
# Processing Record 50 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 12 | cuxhaven
# Processing Record 2 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 3 of Set 12 | karratha
# Processing Record 4 of Set 12 | rocha
# Processing Record 5 of Set 12 | xiangdong
# City not found. Skipping...
# Processing Record 6 of Set 12 | kandrian
# Processing Record 7 of Set 12 | barwani
# Processing Record 8 of Set 12 | portland
# Processing Record 9 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 12 | gasa
# Processing Record 11 of Set 12 | bras-panon
# Processing Record 12 of Set 12 | lasa
# Processing Record 13 of Set 12 | bandarbeyla
# Processing Record 14 of Set 12 | sulphur springs
# Processing Record 15 of Set 12 | raudeberg
# Processing Record 16 of Set 12 | west wendover
# Processing Record 17 of Set 12 | feni
# Processing Record 18 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 12 | dondo
# Processing Record 20 of Set 12 | dymer
# Processing Record 21 of Set 12 | vypolzovo
# Processing Record 22 of Set 12 | goya
# Processing Record 23 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 12 | oranjemund
# Processing Record 25 of Set 12 | dabola
# Processing Record 26 of Set 12 | basco
# Processing Record 27 of Set 12 | shubarshi
# Processing Record 28 of Set 12 | makung
# City not found. Skipping...
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | bago
# Processing Record 31 of Set 12 | demyansk
# Processing Record 32 of Set 12 | luanda
# Processing Record 33 of Set 12 | husavik
# Processing Record 34 of Set 12 | san ramon
# Processing Record 35 of Set 12 | vanavara
# Processing Record 36 of Set 12 | puerto penasco
# Processing Record 37 of Set 12 | taupo
# Processing Record 38 of Set 12 | lagoa
# Processing Record 39 of Set 12 | saint-augustin
# Processing Record 40 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 41 of Set 12 | makakilo city
# Processing Record 42 of Set 12 | tokur
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 12 | mount pleasant
# Processing Record 47 of Set 12 | mato verde
# Processing Record 48 of Set 12 | kassala
# Processing Record 49 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 50 of Set 12 | hastings
# Processing Record 1 of Set 13 | makat
# Processing Record 2 of Set 13 | okhotsk
# Processing Record 3 of Set 13 | shreveport
# Processing Record 4 of Set 13 | yaan
# Processing Record 5 of Set 13 | mayumba
# Processing Record 6 of Set 13 | ketchikan
# Processing Record 7 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 8 of Set 13 | dajal
# Processing Record 9 of Set 13 | spornoye
# Processing Record 10 of Set 13 | nortelandia
# Processing Record 11 of Set 13 | goundam
# Processing Record 12 of Set 13 | dolinsk
# Processing Record 13 of Set 13 | richards bay
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | labytnangi
# Processing Record 16 of Set 13 | novyy urengoy
# Processing Record 17 of Set 13 | solikamsk
# Processing Record 18 of Set 13 | senneterre
# Processing Record 19 of Set 13 | port blair
# Processing Record 20 of Set 13 | belmonte
# Processing Record 21 of Set 13 | baoning
# Processing Record 22 of Set 13 | burgos
# Processing Record 23 of Set 13 | kupang
# Processing Record 24 of Set 13 | allanridge
# Processing Record 25 of Set 13 | praia
# Processing Record 26 of Set 13 | zalantun
# Processing Record 27 of Set 13 | lar
# Processing Record 28 of Set 13 | manali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

len(city_data)
# Out:
# 571

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pisco      PE -13.7000  -76.2167     77.05        78           0
# 1   Yellowknife      CA  62.4560 -114.3525      0.12        60          20
# 2  Saint George      US  37.1041 -113.5841     67.24        64          75
# 3      Hamilton      US  39.1834  -84.5333     46.76        54           0
# 4        Hobart      AU -42.8794  147.3294     58.26        69          40
# 5    Codrington      AU -38.2667  141.9667     56.30        93          79
# 6   Port Alfred      ZA -33.5906   26.8910     66.18        83          86
# 7     Carnarvon      AU -24.8667  113.6333     75.22        76           0
# 8          Rush      IE  53.5223   -6.0931     50.95        94          75
# 9          Puga      MX  21.5833 -104.8167     82.47        50          75
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1       14.97          few clouds
# 2        8.99       broken clouds
# 3       10.36           clear sky
# 4       10.36    scattered clouds
# 5        4.83       broken clouds
# 6        4.00     overcast clouds
# 7       23.42           clear sky
# 8       12.66       broken clouds
# 9        6.91       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# List already in order due to putting in order when calling from url
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pisco      PE -13.7000  -76.2167     77.05        78           0
# 1   Yellowknife      CA  62.4560 -114.3525      0.12        60          20
# 2  Saint George      US  37.1041 -113.5841     67.24        64          75
# 3      Hamilton      US  39.1834  -84.5333     46.76        54           0
# 4        Hobart      AU -42.8794  147.3294     58.26        69          40
# 5    Codrington      AU -38.2667  141.9667     56.30        93          79
# 6   Port Alfred      ZA -33.5906   26.8910     66.18        83          86
# 7     Carnarvon      AU -24.8667  113.6333     75.22        76           0
# 8          Rush      IE  53.5223   -6.0931     50.95        94          75
# 9          Puga      MX  21.5833 -104.8167     82.47        50          75
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1       14.97          few clouds
# 2        8.99       broken clouds
# 3       10.36           clear sky
# 4       10.36    scattered clouds
# 5        4.83       broken clouds
# 6        4.00     overcast clouds
# 7       23.42           clear sky
# 8       12.66       broken clouds
# 9        6.91       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
